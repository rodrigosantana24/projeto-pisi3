# %% [markdown]
# # Importações

# %%
#!pip install scikit-learn shap pandas numpy matplotlib xgboost seaborn

# %%
import pickle
import shap
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np  

# Pré-processamento e pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# Modelos de ML
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# Validação e busca de hiperparâmetros
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV
from scipy.stats import randint, uniform, loguniform

# Métricas
from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, r2_score

# Transformadores personalizados
from transformers import DateFeatureExtractor, CapTransformer, RareCategoryGrouper, TopNMultiLabelTransformer, BudgetRuntimeRatioTransformer

# %% [markdown]
# # Carregando dataset

# %%
df = pd.read_csv('../data/filmes_filtrados_credits.csv')

# %% [markdown]
# # Dividindo os dados
# - X_train, X_test, y_train, y_test

# %%
numerical_cols = ['popularity', 'budget', 'runtime', 'budget_runtime_ratio']
categorical_col = ['original_language']
date_column = 'release_date'

X = df.drop(columns=['vote_average'])
y = df['vote_average']

# Dividindo o dataset em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=87)

# %% [markdown]
# # Transformadores
# - MultiLabelBinarize -> Generos Cinematográficos, Produtora e Atores
# - Data -> Extrai o ano e o mês das datas
# - Outliers -> Cap, Log + Cap, Winsorizer
# - Agrupamento de categorias raras -> original language
# - Criação da feature budget_runtime_ratio

# %%
# Transformers personalizados por coluna
credits_transformer = TopNMultiLabelTransformer(top_n=60, prefix='credits')
genres_transformer = TopNMultiLabelTransformer(top_n=20, prefix='genre')
prod_companies_transformer = TopNMultiLabelTransformer(top_n=60, prefix='prod_company')

# %% [markdown]
# # Treinamento
# - Modelo XGBRegressor
# - Modelo SVR
# - Modelo RandomForest

# %% [markdown]
# ### Definindo Kf

# %%
# Definindo o KFold para o cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=87)

# %% [markdown]
# ### XGBRegressor

# %%
# Numérico
num_pipeline = Pipeline([
    ('cap', CapTransformer(columns=numerical_cols)),
    ('scale', StandardScaler())
])

# Categórico 
cat_pipeline = Pipeline([
    ('rare', RareCategoryGrouper(column='original_language', top_n=10, other_label='Other')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# Pré-processamento geral com ColumnTransformer
preprocessor = ColumnTransformer([
    ('num', num_pipeline, numerical_cols),
    ('cat', cat_pipeline, categorical_col),
    ('credits', credits_transformer, 'credits'),
    ('genres', genres_transformer, 'genres'),
    ('prod_companies', prod_companies_transformer, 'production_companies')
], remainder='passthrough')


pipeline = Pipeline([
    ('budget_ratio', BudgetRuntimeRatioTransformer()),
    ('date', DateFeatureExtractor(date_column=date_column)),
    ('preprocess', preprocessor),
    ('regressor', XGBRegressor(objective='reg:squarederror', random_state=87, n_jobs=-1))
])

param_dist = {
    'regressor__n_estimators': randint(100, 300),
    'regressor__max_depth': randint(3, 10),
    'regressor__learning_rate': uniform(0.01, 0.3),
    'regressor__subsample': uniform(0.7, 0.3),
    'regressor__colsample_bytree': uniform(0.7, 0.3),
}


XGBRegressor_rand = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_dist,
    n_iter=30,
    cv=kf,
    scoring='r2',
    random_state=87,
    verbose=2,
    n_jobs=-1
)

XGBRegressor_rand.fit(X_train, y_train)

print("Melhores parâmetros:", XGBRegressor_rand.best_params_)
print("Melhor R² (validação cruzada):", XGBRegressor_rand.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Melhores parâmetros: {'regressor__colsample_bytree': np.float64(0.8696231377727208), 'regressor__learning_rate': np.float64(0.05992056035524427), 'regressor__max_depth': 5, 'regressor__n_estimators': 241, 'regressor__subsample': np.float64(0.8173221947525602)}
# Melhor R² (validação cruzada): 0.4980542795679779

# %% [markdown]
# ### SVR

# %%
# Numérico
num_pipeline = Pipeline([
    ('cap', CapTransformer(columns=numerical_cols)),
    ('scale', StandardScaler())
])

# Categórico
cat_pipeline = Pipeline([
    ('rare', RareCategoryGrouper(column='original_language', top_n=10, other_label='Other')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# Pré-processamento completo
preprocessor = ColumnTransformer([
    ('num', num_pipeline, numerical_cols),
    ('cat', cat_pipeline, categorical_col),
    ('credits', credits_transformer, 'credits'),
    ('genres', genres_transformer, 'genres'),
    ('prod_companies', prod_companies_transformer, 'production_companies')
], remainder='passthrough')



pipeline_svr = Pipeline([
    ('budget_ratio', BudgetRuntimeRatioTransformer()),
    ('date', DateFeatureExtractor(date_column=date_column)),
    ('preprocess', preprocessor),
    ('regressor', SVR())
])

param_dist_svr = {
    'regressor__kernel': ['rbf', 'linear'],
    'regressor__C': loguniform(1e-2, 1e2),
    'regressor__epsilon': uniform(0.01, 0.3),
    'regressor__gamma': ['scale', 'auto']
}

svm_rand = RandomizedSearchCV(
    estimator=pipeline_svr,
    param_distributions=param_dist_svr,
    n_iter=20,
    cv=kf,
    scoring='r2',
    random_state=87,
    verbose=2,
    n_jobs=-1
)

svm_rand.fit(X_train, y_train)
print("Melhores parâmetros SVR:", svm_rand.best_params_)
print("Melhor R² (CV) SVR:", svm_rand.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Melhores parâmetros SVR: {'regressor__C': np.float64(4.217516020234043), 'regressor__epsilon': np.float64(0.29647041307396826), 'regressor__gamma': 'auto', 'regressor__kernel': 'rbf'}
# Melhor R² (CV) SVR: 0.47050852828571327

# %% [markdown]
# ### RandomForest

# %%
# Numérico
num_pipeline = Pipeline([
    ('cap', CapTransformer(columns=numerical_cols)),
    ('scale', StandardScaler())
])

# Categórico
cat_pipeline = Pipeline([
    ('rare', RareCategoryGrouper(column='original_language', top_n=10, other_label='Other')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# Pré-processamento completo
preprocessor = ColumnTransformer([
    ('num', num_pipeline, numerical_cols),
    ('cat', cat_pipeline, categorical_col),
    ('credits', credits_transformer, 'credits'),
    ('genres', genres_transformer, 'genres'),
    ('prod_companies', prod_companies_transformer, 'production_companies')
], remainder='passthrough')

pipeline_rf = Pipeline([
    ('budget_ratio', BudgetRuntimeRatioTransformer()),
    ('date', DateFeatureExtractor(date_column=date_column)),
    ('preprocess', preprocessor),
    ('regressor', RandomForestRegressor(random_state=87, n_jobs=-1))
])

param_dist_rf = {
    'regressor__n_estimators': randint(100, 500),
    'regressor__max_depth': randint(3, 20),
    'regressor__min_samples_split': randint(2, 10),
    'regressor__min_samples_leaf': randint(1, 10),
    'regressor__max_features': ['sqrt', 'log2', None]
}

rf_rand = RandomizedSearchCV(
    estimator=pipeline_rf,
    param_distributions=param_dist_rf,
    n_iter=30,
    cv=kf,
    scoring='r2',
    error_score='raise',
    random_state=87,
    verbose=2,
    n_jobs=-1
)

rf_rand.fit(X_train, y_train)
print("Melhores parâmetros RF:", rf_rand.best_params_)
print("Melhor R² (CV) RF:", rf_rand.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Melhores parâmetros RF: {'regressor__max_depth': 14, 'regressor__max_features': None, 'regressor__min_samples_leaf': 4, 'regressor__min_samples_split': 2, 'regressor__n_estimators': 376}
# Melhor R² (CV) RF: 0.46823092995495796

# %% [markdown]
# # Avaliação dos modelos

# %%
def evaluate_model(model_name, model, X_test, y_test):
    y_pred = model.predict(X_test)
    return {
        'Modelo': model_name,
        'R²': r2_score(y_test, y_pred),
        'MAE': mean_absolute_error(y_test, y_pred),
        'RMSE': np.sqrt(mean_squared_error(y_test, y_pred)),
        'MedAE': median_absolute_error(y_test, y_pred)
    }

# %%
results = []
results.append(evaluate_model("XGBRegressor", XGBRegressor_rand.best_estimator_, X_test, y_test))
print(results)
# Out:
# [{'Modelo': 'XGBRegressor', 'R²': 0.5071375310581621, 'MAE': 0.4890054096948103, 'RMSE': np.float64(0.6401990124242565), 'MedAE': 0.3925948448181149}]

# %%
results = []
results.append(evaluate_model("XGBRegressor", XGBRegressor_rand.best_estimator_, X_test, y_test))
results.append(evaluate_model("RandomForestRegressor", rf_rand.best_estimator_, X_test, y_test))
results.append(evaluate_model("SVR", svm_rand.best_estimator_, X_test, y_test))
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                   Modelo        R²       MAE      RMSE     MedAE
# 0           XGBRegressor  0.507138  0.489005  0.640199  0.392595
# 1  RandomForestRegressor  0.471798  0.507687  0.662754  0.405450
# 2                    SVR  0.459549  0.508660  0.670395  0.398645

# %% [markdown]
# # Graficos

# %% [markdown]
# ## Shap

# %%
# 1. Obter o melhor pipeline treinado
best_pipeline = XGBRegressor_rand.best_estimator_

# 2. Criar um pipeline APENAS com os passos de pré-processamento
preprocessing_pipeline = Pipeline(best_pipeline.steps[:-1])
X_train_transformed = preprocessing_pipeline.transform(X_train)


# 3. Obter os nomes das features do ColumnTransformer (que é o passo 'preprocess')
col_transformer = best_pipeline.named_steps['preprocess']
feature_names = col_transformer.get_feature_names_out()

# 4. Criar um DataFrame com os dados transformados para melhor visualização no SHAP
X_train_transformed_df = pd.DataFrame(X_train_transformed, columns=feature_names)

# 5. Extrair o modelo final e calcular os valores SHAP
xgb_model = best_pipeline.named_steps['regressor']
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer(X_train_transformed_df) # A API moderna do SHAP usa o explainer como uma função
print("Valores SHAP calculados com sucesso. Gerando gráficos...")

# 6. Gerar os gráficos
plt.figure()
plt.title("SHAP Summary Plot (Beeswarm)")
shap.summary_plot(shap_values, X_train_transformed_df, show=False)
plt.tight_layout() 
plt.show()
plt.figure()
plt.title("Importância Média das Top 40 Features (SHAP Bar Plot)")
shap.summary_plot(shap_values, X_train_transformed_df, plot_type="bar", show=False, max_display=40)
plt.tight_layout()
plt.show()
# Out:
# Valores SHAP calculados com sucesso. Gerando gráficos...

# %% [markdown]
# ## Importance

# %%
feature_importance = np.abs(shap_values.values).mean(axis=0)
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'SHAP Importance': feature_importance
})

sorted_importance_df = importance_df.sort_values(
    by='SHAP Importance', 
    ascending=False
).reset_index(drop=True)

print("Ranking de Importância das Features (baseado em SHAP):")
pd.set_option('display.max_rows', None)
print(len(sorted_importance_df))
display(sorted_importance_df)
# Out:
# Ranking de Importância das Features (baseado em SHAP):
# 159
#                                                Feature  SHAP Importance
# 0                                      num__popularity         0.282606
# 1                                         num__runtime         0.229076
# 2                                      remainder__year         0.142232
# 3                                  genres__genre_Drama         0.141840
# 4                            cat__original_language_en         0.089758
# 5                            num__budget_runtime_ratio         0.085547
# 6                                 genres__genre_Horror         0.074909
# 7                                 genres__genre_Action         0.069541
# 8                              genres__genre_Animation         0.045438
# 9                                          num__budget         0.028582
# 10                       genres__genre_Science Fiction         0.027141
# 11                             genres__genre_Adventure         0.026507
# 12                                    remainder__month         0.021789
# 13                              genres__genre_Thriller         0.015154
# 14                           genres__genre_Documentary         0.014915
# 15                        cat__original_language_Other         0.012715
# 16                                 genres__genre_Crime         0.012247
# 17                                genres__genre_Comedy         0.010196
# 18                               genres__genre_Fantasy         0.008949
# 19                                genres__genre_Family         0.005661
# 20                               genres__genre_History         0.005370
# 21                               genres__genre_Romance         0.005275
# 22                                 genres__genre_Music         0.004792
# 23                           cat__original_language_fr         0.003209
# 24                                   genres__genre_War         0.003048
# 25                           cat__original_language_ja         0.002969
# 26                           cat__original_language_hi         0.002836
# 27      prod_companies__prod_company_Film4 Productions         0.002694
# 28                               genres__genre_Mystery         0.002590
# 29                 prod_companies__prod_company_Canal+         0.002568
# 30      prod_companies__prod_company_Columbia Pictures         0.002479
# 31            prod_companies__prod_company_StudioCanal         0.002442
# 32                 credits__credits_Sylvester Stallone         0.002245
# 33                  credits__credits_Samuel L. Jackson         0.001973
# 34         prod_companies__prod_company_United Artists         0.001930
# 35                       credits__credits_Nicolas Cage         0.001725
# 36       prod_companies__prod_company_Millennium Films         0.001642
# 37        prod_companies__prod_company_Dimension Films         0.001597
# 38   prod_companies__prod_company_Amblin Entertainment         0.001563
# 39    prod_companies__prod_company_DreamWorks Pictures         0.001493
# 40                prod_companies__prod_company_Miramax         0.001335
# 41                           cat__original_language_ko         0.001327
# 42                       credits__credits_Bruce Willis         0.001315
# 43                 prod_companies__prod_company_Outros         0.001306
# 44                                credits__credits_woo         0.001278
# 45   prod_companies__prod_company_Scott Rudin Produ...         0.001218
# 46         prod_companies__prod_company_Focus Features         0.001194
# 47     prod_companies__prod_company_Universal Pictures         0.001148
# 48   prod_companies__prod_company_New Regency Pictures         0.001085
# 49                           cat__original_language_it         0.001081
# 50                               credits__credits_Jean         0.001036
# 51   prod_companies__prod_company_The Weinstein Com...         0.001014
# 52                               genres__genre_Western         0.000975
# 53                      credits__credits_Michael Caine         0.000966
# 54                              genres__genre_TV Movie         0.000918
# 55                     credits__credits_Robert De Niro         0.000889
# 56              prod_companies__prod_company_Paramount         0.000869
# 57                       credits__credits_Meryl Streep         0.000859
# 58    prod_companies__prod_company_Working Title Films         0.000845
# 59       prod_companies__prod_company_20th Century Fox         0.000795
# 60                                credits__credits_hee         0.000782
# 61    prod_companies__prod_company_Davis Entertainment         0.000753
# 62                        credits__credits_Liam Neeson         0.000745
# 63   prod_companies__prod_company_Village Roadshow ...         0.000738
# 64                        credits__credits_Bill Murray         0.000737
# 65                       credits__credits_Clint Howard         0.000700
# 66                   credits__credits_Antonio Banderas         0.000696
# 67                       credits__credits_Alec Baldwin         0.000679
# 68   prod_companies__prod_company_Warner Bros. Pict...         0.000666
# 69   prod_companies__prod_company_Fox Searchlight P...         0.000666
# 70                      credits__credits_Nicole Kidman         0.000647
# 71   prod_companies__prod_company_PolyGram Filmed E...         0.000635
# 72                      credits__credits_Steve Buscemi         0.000615
# 73                       credits__credits_Frank Welker         0.000592
# 74                          credits__credits_Tom Hanks         0.000589
# 75                                credits__credits_jin         0.000571
# 76             prod_companies__prod_company_Atresmedia         0.000571
# 77                    prod_companies__prod_company_CNC         0.000563
# 78                       credits__credits_Willem Dafoe         0.000536
# 79   prod_companies__prod_company_Scott Free Produc...         0.000532
# 80                           cat__original_language_es         0.000498
# 81                              credits__credits_Marie         0.000492
# 82   prod_companies__prod_company_Summit Entertainment         0.000487
# 83                         credits__credits_Matt Damon         0.000456
# 84                               credits__credits_seok         0.000455
# 85                      credits__credits_Paul Giamatti         0.000455
# 86                     credits__credits_Cate Blanchett         0.000454
# 87          prod_companies__prod_company_Original Film         0.000445
# 88                         credits__credits_Jack Black         0.000435
# 89            prod_companies__prod_company_Screen Gems         0.000402
# 90                   credits__credits_Claude Van Damme         0.000377
# 91        prod_companies__prod_company_France 3 Cinéma         0.000366
# 92   prod_companies__prod_company_Walt Disney Pictures         0.000358
# 93             prod_companies__prod_company_Wild Bunch         0.000356
# 94        prod_companies__prod_company_New Line Cinema         0.000345
# 95        prod_companies__prod_company_Silver Pictures         0.000340
# 96                           cat__original_language_ru         0.000300
# 97                       credits__credits_Bess Flowers         0.000299
# 98              prod_companies__prod_company_Lionsgate         0.000284
# 99                        credits__credits_Keith David         0.000282
# 100                          cat__original_language_de         0.000282
# 101  prod_companies__prod_company_Blumhouse Product...         0.000268
# 102                 prod_companies__prod_company_Pathé         0.000248
# 103    prod_companies__prod_company_Dune Entertainment         0.000247
# 104        prod_companies__prod_company_Orion Pictures         0.000240
# 105      prod_companies__prod_company_Relativity Media         0.000238
# 106                 credits__credits_Robert Downey Jr.         0.000235
# 107    prod_companies__prod_company_ARTE France Cinéma         0.000228
# 108                       credits__credits_Johnny Depp         0.000221
# 109                             credits__credits_Smith         0.000220
# 110                    credits__credits_Morgan Freeman         0.000216
# 111               prod_companies__prod_company_Goldwyn         0.000213
# 112  prod_companies__prod_company_TF1 Films Production         0.000213
# 113                      credits__credits_Keanu Reeves         0.000211
# 114           prod_companies__prod_company_Film i Väst         0.000210
# 115                       credits__credits_Danny Trejo         0.000206
# 116                       credits__credits_Dan Aykroyd         0.000206
# 117     prod_companies__prod_company_Fox 2000 Pictures         0.000204
# 118                  credits__credits_Sigourney Weaver         0.000202
# 119                          cat__original_language_zh         0.000200
# 120  prod_companies__prod_company_Castle Rock Enter...         0.000195
# 121                        credits__credits_Joe Chrest         0.000195
# 122   prod_companies__prod_company_Touchstone Pictures         0.000193
# 123                      credits__credits_J.K. Simmons         0.000192
# 124                credits__credits_Christopher Walken         0.000182
# 125                                credits__credits_ho         0.000168
# 126               prod_companies__prod_company_Gaumont         0.000165
# 127       prod_companies__prod_company_France 2 Cinéma         0.000159
# 128      prod_companies__prod_company_TriStar Pictures         0.000156
# 129                      credits__credits_Stephen Root         0.000155
# 130                       credits__credits_Owen Wilson         0.000140
# 131                 prod_companies__prod_company_Ciné+         0.000139
# 132   prod_companies__prod_company_Regency Enterprises         0.000128
# 133       prod_companies__prod_company_Ingenious Media         0.000125
# 134                             credits__credits_Jones         0.000120
# 135                    credits__credits_Susan Sarandon         0.000114
# 136                   credits__credits_Fred Tatasciore         0.000106
# 137                   credits__credits_Richard Jenkins         0.000087
# 138                              credits__credits_Anne         0.000066
# 139                    credits__credits_Robin Williams         0.000064
# 140                             credits__credits_young         0.000025
# 141                 credits__credits_Donald Sutherland         0.000022
# 142                 prod_companies__prod_company_Metro         0.000021
# 143                   credits__credits_Forest Whitaker         0.000018
# 144    prod_companies__prod_company_Hollywood Pictures         0.000017
# 145                     credits__credits_Stanley Tucci         0.000013
# 146                    credits__credits_John Leguizamo         0.000012
# 147                               credits__credits_won         0.000011
# 148                   credits__credits_Woody Harrelson         0.000010
# 149                               credits__credits_soo         0.000007
# 150  prod_companies__prod_company_Imagine Entertain...         0.000007
# 151                      credits__credits_Danny DeVito         0.000000
# 152                            credits__credits_Outros         0.000000
# 153                credits__credits_Thomas Rosales Jr.         0.000000
# 154                 prod_companies__prod_company_Mayer         0.000000
# 155                               genres__genre_Outros         0.000000
# 156     prod_companies__prod_company_TSG Entertainment         0.000000
# 157      prod_companies__prod_company_CJ Entertainment         0.000000
# 158            prod_companies__prod_company_EuropaCorp         0.000000

# %% [markdown]
# # Gerando Pickle

# %%
'''
with open(best_model.pkl', 'wb') as f:
    pickle.dump(XGBRegressor_rand, f)

with open('svr_pipeline.pkl', 'wb') as f:
    pickle.dump(svm_rand, f)

with open('rf_pipeline.pkl', 'wb') as f:
    pickle.dump(rf_rand, f)
'''
